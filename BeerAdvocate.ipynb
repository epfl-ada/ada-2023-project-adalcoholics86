# %%
import pandas as pd 
import numpy as np

# %%
#BeerAdvocate website data

df_beer = pd.read_csv("BeerAdvocate/beers.csv", index_col='beer_id')
df_breweries  = pd.read_csv("BeerAdvocate/breweries.csv")
df_users = pd.read_csv("BeerAdvocate/users.csv")
df_rating = pd.read_csv("BeerAdvocate/ratings.txt",  on_bad_lines='skip')

# %%
df_breweries
# Out:
#           id                       location  \
# 0      39912                     Kyrgyzstan
# 1      39913                     Kyrgyzstan
# 2      39914                     Kyrgyzstan
# 3      39915                     Kyrgyzstan
# 4      39916                     Kyrgyzstan
# ...      ...                            ...
# 16753    128                        Germany
# 16754   5023                          Aruba
# 16755   1573        United States, New York
# 16756  16186  United States, North Carolina
# 16757   1138        United States, Maryland
#
#                                      name  nbr_beers
# 0                  Abdysh-Ata (Абдыш Ата)          5
# 1                             Arpa (АРПА)          1
# 2                               Bear Beer          4
# 3                             Blonder Pub          4
# 4                            Kellers Bier          2
# ...                                   ...        ...
# 16753  Privatbrauerei Franz Joseph Sailer          6
# ...

# %%
#group the beer by breweries
df_beer_breweries = df_beer.groupby('brewery_id')
display(df_beer_breweries.head())
# Out:
#                   beer_name  brewery_id                         brewery_name  \
# beer_id
# 166064     Nashe Moskovskoe       39912               Abdysh-Ata (Абдыш Ата)
# 166065      Nashe Pivovskoe       39912               Abdysh-Ata (Абдыш Ата)
# 166066   Nashe Shakhterskoe       39912               Abdysh-Ata (Абдыш Ата)
# 166067   Nashe Zhigulevskoe       39912               Abdysh-Ata (Абдыш Ата)
# 166063               Zhivoe       39912               Abdysh-Ata (Абдыш Ата)
# ...                     ...         ...                                  ...
# 19147                   Alt         885  Summit Station Restaurant & Brewery
# 19144       Blueberry Wheat         885  Summit Station Restaurant & Brewery
# 27861        Centennial Ale         885  Summit Station Restaurant & Brewery
# 19143             Cream Ale         885  Summit Station Restaurant & Brewery
# 19149         Diamond Stout         885  Summit Station Restaurant & Brewery
#
# ...

# %%
#Drop the row of df_beer with many NaN values
df_beer.head(30)
# Out:
#                         beer_name  brewery_id  \
# beer_id
# 166064           Nashe Moskovskoe       39912
# 166065            Nashe Pivovskoe       39912
# 166066         Nashe Shakhterskoe       39912
# 166067         Nashe Zhigulevskoe       39912
# 166063                     Zhivoe       39912
# 166068                       Arpa       39913
# 166071                       Eles       39914
# 166072                 Eles Light       39914
# 166074             Toroz Svetloye       39914
# 166076              Toroz Temnoye       39914
# 166082              English Staut       39915
# 166083                 Green Beer       39915
# 166080                  Irish Red       39915
# 166078                      Light       39915
# 166084     Kellers Bier Filtrovne       39916
# 166085   Kellers Bier Nefiltrovne       39916
# 164772                     Kolsch       16052
# 164773               Myunkhenskoe       16052
# 164774                     Temnoe       16052
# ...

# %%
#df_breweries[df_breweries.location == 'Switzerland'].head(20)
df_breweries
# Out:
#           id                       location  \
# 0      39912                     Kyrgyzstan
# 1      39913                     Kyrgyzstan
# 2      39914                     Kyrgyzstan
# 3      39915                     Kyrgyzstan
# 4      39916                     Kyrgyzstan
# ...      ...                            ...
# 16753    128                        Germany
# 16754   5023                          Aruba
# 16755   1573        United States, New York
# 16756  16186  United States, North Carolina
# 16757   1138        United States, Maryland
#
#                                      name  nbr_beers
# 0                  Abdysh-Ata (Абдыш Ата)          5
# 1                             Arpa (АРПА)          1
# 2                               Bear Beer          4
# 3                             Blonder Pub          4
# 4                            Kellers Bier          2
# ...                                   ...        ...
# 16753  Privatbrauerei Franz Joseph Sailer          6
# ...

# %%
df_users
# Out:
#         nbr_ratings  nbr_reviews                user_id        user_name  \
# 0              7820          465         nmann08.184925          nmann08
# 1              2521         2504     stjamesgate.163714      StJamesGate
# 2              1797         1143          mdagnew.19527          mdagnew
# 3                31           31  helloloser12345.10867  helloloser12345
# 4               604          604        cypressbob.3708       cypressbob
# ...             ...          ...                    ...              ...
# 153699            1            1         everman.532342          Everman
# 153700            1            1      justin0001.352175       Justin0001
# 153701            1            0        kyungsup.982216         Kyungsup
# 153702            1            1          joetex.800347           JoeTex
# 153703            1            1      alexmatt86.313751       Alexmatt86
#
#               joined                   location
# ...

# %%
df_users
# Out:
#         nbr_ratings  nbr_reviews                user_id        user_name  \
# 0              7820          465         nmann08.184925          nmann08
# 1              2521         2504     stjamesgate.163714      StJamesGate
# 2              1797         1143          mdagnew.19527          mdagnew
# 3                31           31  helloloser12345.10867  helloloser12345
# 4               604          604        cypressbob.3708       cypressbob
# ...             ...          ...                    ...              ...
# 153699            1            1         everman.532342          Everman
# 153700            1            1      justin0001.352175       Justin0001
# 153701            1            0        kyungsup.982216         Kyungsup
# 153702            1            1          joetex.800347           JoeTex
# 153703            1            1      alexmatt86.313751       Alexmatt86
#
#               joined                   location
# ...
